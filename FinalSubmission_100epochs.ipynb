# %%
#Import pandas and numpy for data processing
import pandas as pd
import numpy as np

#Import sklearn libraries and packages for test/train data split
from sklearn import datasets, svm, metrics
from sklearn.model_selection import train_test_split

# %%
#Read data
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
#Check data points for data
concrete_data.shape
# Out:
# (1030, 9)

# %%
#Describe dataset
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
#Check for missing data
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
#Split the datasets into training and test

X_train, X_test = train_test_split(concrete_data, test_size=0.3)

# %%
#Break Dataset into predictors and targets for training and test datasets
concrete_data_columns_train = X_train.columns
concrete_data_columns_test = X_test.columns

predictors_train = X_train[concrete_data_columns_train[concrete_data_columns_train != 'Strength']]
target_train = X_train['Strength'] 

predictors_test = X_test[concrete_data_columns_test[concrete_data_columns_test != 'Strength']]
target_test = X_test['Strength']

# %%
#Check predictors dataset
predictors_train.head()
# Out:
#      Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 991   309.9               142.8    111.2  167.8              22.1
# 820   525.0                 0.0      0.0  189.0               0.0
# 934   184.0                86.0    190.0  213.0               6.0
# 334   275.1                 0.0    121.4  159.5               9.9
# 566   255.5               170.3      0.0  185.7               0.0
#
#      Coarse Aggregate  Fine Aggregate  Age
# 991             913.9           651.2   28
# 820            1125.0           613.0  270
# 934             923.0           623.0   28
# 334            1053.6           777.5    3
# 566            1026.6           724.3   28

# %%
#Check target dataset
target_train.head()
# Out:
# 991    38.22
# 820    67.11
# 934    22.93
# 334    23.80
# 566    32.05
# Name: Strength, dtype: float64

# %%
#Normalize data to improve training efficiency
predictors_train_norm = (predictors_train - predictors_train.mean()) / predictors_train.std()
predictors_test_norm = (predictors_test - predictors_test.mean()) / predictors_test.std()
#predictors_norm.head()

predictors_train = predictors_train_norm
predictors_test = predictors_test_norm

# %%
#Saving the columns as n_cols
#n_cols = predictors_norm.shape[1] # number of predictors
n_cols_train = predictors_train.shape[1]
n_cols_test = predictors_test.shape[1]

# %%
#Baseline model code starts here
#Import all the necessary libraries and packages
import keras

from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:522: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# define regression model
import keras.backend as K

def mean_pred(predictors_test, target_test):
    return K.mean(target_test)

def std_pred(predictors_test, target_test):
    return K.std(target_test)

def regression_model():
    # create model - 10 nodes, relu activation function, 'adam' optimizer and 'mean_squared_error'
    #Note - data is not normalized
    model_train = Sequential()
    model_train.add(Dense(10, activation='relu', input_shape=(n_cols_train,)))
    model_train.add(Dense(10, activation='relu'))
    model_train.add(Dense(1))
    
    # compile model
    model_train.compile(optimizer='adam', loss='mean_squared_error',  metrics=[mean_pred, std_pred] )
    return model_train

# %%
# build the model
model_train = regression_model()

# %%
# fit the model - Requested 50 epochs - against test data with the mean, std and the mean squared error
#model_train.fit(predictors_train, target_train, validation_split=0.3, epochs=50, verbose=2)

model_train.fit(predictors_train, target_train, validation_data=(predictors_test,target_test), epochs=100, verbose=2)
# Out:
# Train on 721 samples, validate on 309 samples
# Epoch 1/100
#  - 1s - loss: 1522.5810 - mean_pred: 0.4285 - std_pred: 0.5208 - val_loss: 1522.0518 - val_mean_pred: 0.5885 - val_std_pred: 0.6406
# Epoch 2/100
#  - 0s - loss: 1494.7216 - mean_pred: 0.8078 - std_pred: 0.6493 - val_loss: 1492.5150 - val_mean_pred: 0.9895 - val_std_pred: 0.7897
# Epoch 3/100
#  - 0s - loss: 1463.1774 - mean_pred: 1.2375 - std_pred: 0.8099 - val_loss: 1457.8644 - val_mean_pred: 1.4643 - val_std_pred: 0.9806
# Epoch 4/100
#  - 0s - loss: 1425.2227 - mean_pred: 1.7640 - std_pred: 1.0276 - val_loss: 1415.6840 - val_mean_pred: 2.0537 - val_std_pred: 1.2133
# Epoch 5/100
#  - 0s - loss: 1377.8714 - mean_pred: 2.4256 - std_pred: 1.2733 - val_loss: 1363.4352 - val_mean_pred: 2.7978 - val_std_pred: 1.5078
# Epoch 6/100
#  - 0s - loss: 1318.6988 - mean_pred: 3.2789 - std_pred: 1.6304 - val_loss: 1296.5609 - val_mean_pred: 3.7732 - val_std_pred: 1.9343
# Epoch 7/100
#  - 0s - loss: 1243.4830 - mean_pred: 4.3819 - std_pred: 2.1018 - val_loss: 1214.0396 - val_mean_pred: 5.0097 - val_std_pred: 2.5141
# Epoch 8/100
#  - 0s - loss: 1153.2724 - mean_pred: 5.7627 - std_pred: 2.7169 - val_loss: 1113.1080 - val_mean_pred: 6.5814 - val_std_pred: 3.2504
# Epoch 9/100
#  - 0s - loss: 1046.0523 - mean_pred: 7.4855 - std_pred: 3.5340 - val_loss: 997.8336 - val_mean_pred: 8.4822 - val_std_pred: 4.2137
# Epoch 10/100
#  - 0s - loss: 926.5580 - mean_pred: 9.5454 - std_pred: 4.5234 - val_loss: 876.9548 - val_mean_pred: 10.6552 - val_std_pred: 5.2998
# Epoch 11/100
#  - 0s - loss: 803.1050 - mean_pred: 11.8739 - std_pred: 5.6295 - val_loss: 753.9120 - val_mean_pred: 13.1240 - val_std_pred: 6.5670
# Epoch 12/100
#  - 0s - loss: 683.1553 - mean_pred: 14.4227 - std_pred: 6.8657 - val_loss: 636.3772 - val_mean_pred: 15.8088 - val_std_pred: 7.9701
# Epoch 13/100
#  - 0s - loss: 572.1965 - mean_pred: 17.1248 - std_pred: 8.1926 - val_loss: 537.2307 - val_mean_pred: 18.4913 - val_std_pred: 9.2633
# Epoch 14/100
#  - 0s - loss: 479.0421 - mean_pred: 19.8133 - std_pred: 9.4399 - val_loss: 455.0307 - val_mean_pred: 21.1350 - val_std_pred: 10.5661
# Epoch 15/100
#  - 0s - loss: 404.8372 - mean_pred: 22.4361 - std_pred: 10.6204 - val_loss: 391.4521 - val_mean_pred: 23.6875 - val_std_pred: 11.7558
# Epoch 16/100
#  - 0s - loss: 349.8431 - mean_pred: 24.8090 - std_pred: 11.6601 - val_loss: 347.4160 - val_mean_pred: 25.8741 - val_std_pred: 12.6637
# Epoch 17/100
#  - 0s - loss: 311.2716 - mean_pred: 26.8685 - std_pred: 12.4020 - val_loss: 317.0494 - val_mean_pred: 27.7154 - val_std_pred: 13.4107
# Epoch 18/100
#  - 0s - loss: 284.2905 - mean_pred: 28.5232 - std_pred: 13.0083 - val_loss: 296.0984 - val_mean_pred: 29.2209 - val_std_pred: 13.9097
# Epoch 19/100
#  - 0s - loss: 265.7008 - mean_pred: 29.9464 - std_pred: 13.5199 - val_loss: 280.9338 - val_mean_pred: 30.4562 - val_std_pred: 14.2796
# Epoch 20/100
#  - 0s - loss: 252.6020 - mean_pred: 31.0187 - std_pred: 13.8363 - val_loss: 269.7033 - val_mean_pred: 31.4125 - val_std_pred: 14.4532
# Epoch 21/100
#  - 0s - loss: 241.7508 - mean_pred: 31.7149 - std_pred: 13.8947 - val_loss: 260.5747 - val_mean_pred: 31.9550 - val_std_pred: 14.4448
# Epoch 22/100
#  - 0s - loss: 233.1952 - mean_pred: 32.2088 - std_pred: 13.7214 - val_loss: 253.1182 - val_mean_pred: 32.3504 - val_std_pred: 14.4299
# Epoch 23/100
#  - 0s - loss: 226.1206 - mean_pred: 32.5599 - std_pred: 13.6515 - val_loss: 245.5786 - val_mean_pred: 32.7048 - val_std_pred: 14.3863
# Epoch 24/100
#  - 0s - loss: 219.5833 - mean_pred: 32.9626 - std_pred: 13.6981 - val_loss: 239.2577 - val_mean_pred: 33.0546 - val_std_pred: 14.3794
# Epoch 25/100
#  - 0s - loss: 213.5760 - mean_pred: 33.2337 - std_pred: 13.7910 - val_loss: 232.8736 - val_mean_pred: 33.2615 - val_std_pred: 14.3199
# Epoch 26/100
#  - 0s - loss: 208.2543 - mean_pred: 33.4703 - std_pred: 13.7224 - val_loss: 227.0893 - val_mean_pred: 33.5210 - val_std_pred: 14.2643
# Epoch 27/100
#  - 0s - loss: 203.3608 - mean_pred: 33.7299 - std_pred: 13.5981 - val_loss: 221.3761 - val_mean_pred: 33.7752 - val_std_pred: 14.2869
# Epoch 28/100
#  - 0s - loss: 198.7799 - mean_pred: 33.7293 - std_pred: 13.6873 - val_loss: 216.1295 - val_mean_pred: 33.6836 - val_std_pred: 14.0962
# Epoch 29/100
#  - 0s - loss: 194.5819 - mean_pred: 33.7840 - std_pred: 13.5069 - val_loss: 211.8325 - val_mean_pred: 33.8284 - val_std_pred: 14.0526
# Epoch 30/100
#  - 0s - loss: 190.7801 - mean_pred: 34.0504 - std_pred: 13.4867 - val_loss: 207.1317 - val_mean_pred: 34.0909 - val_std_pred: 14.0644
# Epoch 31/100
#  - 0s - loss: 186.8210 - mean_pred: 34.1350 - std_pred: 13.4260 - val_loss: 203.0423 - val_mean_pred: 34.1329 - val_std_pred: 13.9675
# Epoch 32/100
#  - 0s - loss: 183.6364 - mean_pred: 34.2591 - std_pred: 13.4549 - val_loss: 199.1008 - val_mean_pred: 34.2515 - val_std_pred: 13.9347
# Epoch 33/100
#  - 0s - loss: 180.4142 - mean_pred: 34.2312 - std_pred: 13.2546 - val_loss: 195.4724 - val_mean_pred: 34.2349 - val_std_pred: 13.8693
# Epoch 34/100
#  - 0s - loss: 177.4385 - mean_pred: 34.3735 - std_pred: 13.2266 - val_loss: 192.2015 - val_mean_pred: 34.4611 - val_std_pred: 13.8843
# Epoch 35/100
#  - 0s - loss: 174.5127 - mean_pred: 34.5312 - std_pred: 13.4049 - val_loss: 189.1613 - val_mean_pred: 34.5759 - val_std_pred: 13.8619
# Epoch 36/100
#  - 0s - loss: 172.2847 - mean_pred: 34.3922 - std_pred: 13.2515 - val_loss: 185.7705 - val_mean_pred: 34.4065 - val_std_pred: 13.7438
# Epoch 37/100
#  - 0s - loss: 169.3206 - mean_pred: 34.5639 - std_pred: 13.3128 - val_loss: 182.6372 - val_mean_pred: 34.6496 - val_std_pred: 13.8462
# Epoch 38/100
#  - 0s - loss: 166.6743 - mean_pred: 34.5618 - std_pred: 13.2200 - val_loss: 179.8174 - val_mean_pred: 34.6324 - val_std_pred: 13.7606
# Epoch 39/100
#  - 0s - loss: 164.2361 - mean_pred: 34.6673 - std_pred: 13.3026 - val_loss: 177.0735 - val_mean_pred: 34.7894 - val_std_pred: 13.7919
# Epoch 40/100
#  - 0s - loss: 162.0897 - mean_pred: 34.7610 - std_pred: 13.3266 - val_loss: 174.6698 - val_mean_pred: 34.8334 - val_std_pred: 13.7464
# Epoch 41/100
#  - 0s - loss: 160.2355 - mean_pred: 34.8560 - std_pred: 13.1682 - val_loss: 172.4128 - val_mean_pred: 34.9137 - val_std_pred: 13.7443
# Epoch 42/100
#  - 0s - loss: 158.5504 - mean_pred: 34.8781 - std_pred: 13.1898 - val_loss: 170.1619 - val_mean_pred: 34.9184 - val_std_pred: 13.6901
# Epoch 43/100
#  - 0s - loss: 156.6313 - mean_pred: 34.8787 - std_pred: 13.1395 - val_loss: 168.1195 - val_mean_pred: 35.0210 - val_std_pred: 13.7325
# Epoch 44/100
#  - 0s - loss: 155.0835 - mean_pred: 34.8439 - std_pred: 13.1481 - val_loss: 166.2049 - val_mean_pred: 34.9640 - val_std_pred: 13.6295
# Epoch 45/100
#  - 0s - loss: 153.3728 - mean_pred: 34.9681 - std_pred: 13.2287 - val_loss: 164.3291 - val_mean_pred: 35.0529 - val_std_pred: 13.5800
# Epoch 46/100
#  - 0s - loss: 151.9415 - mean_pred: 34.9003 - std_pred: 13.0169 - val_loss: 162.4056 - val_mean_pred: 35.0314 - val_std_pred: 13.5495
# Epoch 47/100
#  - 0s - loss: 150.5257 - mean_pred: 34.9994 - std_pred: 12.9571 - val_loss: 160.4027 - val_mean_pred: 35.1266 - val_std_pred: 13.5973
# Epoch 48/100
#  - 0s - loss: 149.1893 - mean_pred: 35.0938 - std_pred: 13.0589 - val_loss: 158.9584 - val_mean_pred: 35.1652 - val_std_pred: 13.5886
# Epoch 49/100
#  - 0s - loss: 147.9200 - mean_pred: 34.9983 - std_pred: 13.1233 - val_loss: 157.3222 - val_mean_pred: 35.0790 - val_std_pred: 13.4949
# Epoch 50/100
#  - 0s - loss: 146.7417 - mean_pred: 35.0013 - std_pred: 13.0174 - val_loss: 155.9057 - val_mean_pred: 35.1862 - val_std_pred: 13.4951
# Epoch 51/100
#  - 0s - loss: 145.6691 - mean_pred: 35.1700 - std_pred: 13.0696 - val_loss: 154.5395 - val_mean_pred: 35.3016 - val_std_pred: 13.5308
# Epoch 52/100
#  - 0s - loss: 144.7344 - mean_pred: 35.1053 - std_pred: 13.1162 - val_loss: 153.0238 - val_mean_pred: 35.1299 - val_std_pred: 13.4517
# Epoch 53/100
#  - 0s - loss: 143.5749 - mean_pred: 35.1996 - std_pred: 13.0442 - val_loss: 152.0141 - val_mean_pred: 35.3997 - val_std_pred: 13.5321
# Epoch 54/100
#  - 0s - loss: 142.3764 - mean_pred: 35.2546 - std_pred: 13.0914 - val_loss: 150.7952 - val_mean_pred: 35.2718 - val_std_pred: 13.4172
# Epoch 55/100
#  - 0s - loss: 141.6219 - mean_pred: 35.0776 - std_pred: 12.8498 - val_loss: 149.9692 - val_mean_pred: 35.2165 - val_std_pred: 13.3167
# Epoch 56/100
#  - 0s - loss: 140.6423 - mean_pred: 35.1942 - std_pred: 13.0927 - val_loss: 148.5355 - val_mean_pred: 35.3889 - val_std_pred: 13.4432
# Epoch 57/100
#  - 0s - loss: 139.5874 - mean_pred: 35.3109 - std_pred: 12.9269 - val_loss: 147.6101 - val_mean_pred: 35.3885 - val_std_pred: 13.3697
# Epoch 58/100
#  - 0s - loss: 138.7527 - mean_pred: 35.2619 - std_pred: 12.8847 - val_loss: 146.4367 - val_mean_pred: 35.4143 - val_std_pred: 13.4098
# Epoch 59/100
#  - 0s - loss: 138.1179 - mean_pred: 35.2093 - std_pred: 12.9933 - val_loss: 145.9650 - val_mean_pred: 35.4089 - val_std_pred: 13.2832
# Epoch 60/100
#  - 0s - loss: 137.0760 - mean_pred: 35.3004 - std_pred: 12.9190 - val_loss: 144.8242 - val_mean_pred: 35.3321 - val_std_pred: 13.2306
# Epoch 61/100
#  - 0s - loss: 136.1990 - mean_pred: 35.2958 - std_pred: 13.0157 - val_loss: 143.7888 - val_mean_pred: 35.4443 - val_std_pred: 13.2782
# Epoch 62/100
#  - 0s - loss: 135.6246 - mean_pred: 35.2877 - std_pred: 12.9135 - val_loss: 142.7272 - val_mean_pred: 35.3955 - val_std_pred: 13.2371
# Epoch 63/100
#  - 0s - loss: 134.7299 - mean_pred: 35.3538 - std_pred: 12.8989 - val_loss: 142.1501 - val_mean_pred: 35.4283 - val_std_pred: 13.1681
# Epoch 64/100
#  - 0s - loss: 133.8767 - mean_pred: 35.3478 - std_pred: 12.7046 - val_loss: 141.3085 - val_mean_pred: 35.5153 - val_std_pred: 13.1793
# Epoch 65/100
#  - 0s - loss: 133.2496 - mean_pred: 35.4013 - std_pred: 12.7359 - val_loss: 140.8346 - val_mean_pred: 35.5367 - val_std_pred: 13.1496
# Epoch 66/100
#  - 0s - loss: 132.5182 - mean_pred: 35.5102 - std_pred: 12.7793 - val_loss: 139.8453 - val_mean_pred: 35.6118 - val_std_pred: 13.1960
# Epoch 67/100
#  - 0s - loss: 131.9481 - mean_pred: 35.3915 - std_pred: 12.8098 - val_loss: 139.2851 - val_mean_pred: 35.4403 - val_std_pred: 13.0092
# Epoch 68/100
#  - 0s - loss: 131.1444 - mean_pred: 35.3763 - std_pred: 12.6582 - val_loss: 138.3596 - val_mean_pred: 35.5772 - val_std_pred: 13.0729
# Epoch 69/100
#  - 0s - loss: 130.5567 - mean_pred: 35.4848 - std_pred: 12.8004 - val_loss: 137.8063 - val_mean_pred: 35.5663 - val_std_pred: 13.0062
# Epoch 70/100
#  - 0s - loss: 129.9812 - mean_pred: 35.5952 - std_pred: 12.8536 - val_loss: 136.8716 - val_mean_pred: 35.6850 - val_std_pred: 13.1204
# Epoch 71/100
#  - 0s - loss: 129.3048 - mean_pred: 35.5594 - std_pred: 12.6420 - val_loss: 136.3100 - val_mean_pred: 35.5677 - val_std_pred: 13.0290
# Epoch 72/100
#  - 0s - loss: 128.7616 - mean_pred: 35.3374 - std_pred: 12.6602 - val_loss: 135.8765 - val_mean_pred: 35.4721 - val_std_pred: 12.9603
# Epoch 73/100
#  - 0s - loss: 128.0150 - mean_pred: 35.4681 - std_pred: 12.6019 - val_loss: 135.0568 - val_mean_pred: 35.6684 - val_std_pred: 13.0376
# Epoch 74/100
#  - 0s - loss: 127.6258 - mean_pred: 35.5897 - std_pred: 12.8125 - val_loss: 134.3271 - val_mean_pred: 35.7374 - val_std_pred: 13.0923
# Epoch 75/100
#  - 0s - loss: 126.9176 - mean_pred: 35.5227 - std_pred: 12.6626 - val_loss: 133.8901 - val_mean_pred: 35.6038 - val_std_pred: 12.9876
# Epoch 76/100
#  - 0s - loss: 126.4030 - mean_pred: 35.5535 - std_pred: 12.6408 - val_loss: 133.5518 - val_mean_pred: 35.8024 - val_std_pred: 13.0125
# Epoch 77/100
#  - 0s - loss: 125.8930 - mean_pred: 35.7414 - std_pred: 12.7618 - val_loss: 132.7320 - val_mean_pred: 35.8074 - val_std_pred: 13.0674
# Epoch 78/100
#  - 0s - loss: 125.2639 - mean_pred: 35.6131 - std_pred: 12.7490 - val_loss: 132.3740 - val_mean_pred: 35.6328 - val_std_pred: 12.9683
# Epoch 79/100
#  - 0s - loss: 124.7825 - mean_pred: 35.5233 - std_pred: 12.4545 - val_loss: 131.9744 - val_mean_pred: 35.6193 - val_std_pred: 12.9397
# Epoch 80/100
#  - 0s - loss: 124.1799 - mean_pred: 35.5243 - std_pred: 12.7351 - val_loss: 131.4203 - val_mean_pred: 35.6344 - val_std_pred: 12.9608
# Epoch 81/100
#  - 0s - loss: 123.8866 - mean_pred: 35.6311 - std_pred: 12.5613 - val_loss: 131.1390 - val_mean_pred: 35.8144 - val_std_pred: 12.9699
# Epoch 82/100
#  - 0s - loss: 123.2299 - mean_pred: 35.7162 - std_pred: 12.6562 - val_loss: 130.4420 - val_mean_pred: 35.7318 - val_std_pred: 12.9736
# Epoch 83/100
#  - 0s - loss: 122.8324 - mean_pred: 35.6430 - std_pred: 12.6485 - val_loss: 129.8765 - val_mean_pred: 35.7404 - val_std_pred: 12.9399
# Epoch 84/100
#  - 0s - loss: 122.4580 - mean_pred: 35.6630 - std_pred: 12.6714 - val_loss: 129.1558 - val_mean_pred: 35.7876 - val_std_pred: 13.0138
# Epoch 85/100
#  - 0s - loss: 122.1443 - mean_pred: 35.6547 - std_pred: 12.6343 - val_loss: 128.7678 - val_mean_pred: 35.7552 - val_std_pred: 12.9556
# Epoch 86/100
#  - 0s - loss: 121.7232 - mean_pred: 35.5143 - std_pred: 12.4369 - val_loss: 128.8120 - val_mean_pred: 35.6651 - val_std_pred: 12.8183
# Epoch 87/100
#  - 0s - loss: 121.1305 - mean_pred: 35.6163 - std_pred: 12.4241 - val_loss: 128.2871 - val_mean_pred: 35.7711 - val_std_pred: 12.8447
# Epoch 88/100
#  - 0s - loss: 120.7899 - mean_pred: 35.6925 - std_pred: 12.6101 - val_loss: 127.7433 - val_mean_pred: 35.7559 - val_std_pred: 12.8608
# Epoch 89/100
#  - 0s - loss: 120.5404 - mean_pred: 35.7399 - std_pred: 12.4983 - val_loss: 127.5564 - val_mean_pred: 35.9111 - val_std_pred: 12.8683
# Epoch 90/100
#  - 0s - loss: 120.2026 - mean_pred: 35.6454 - std_pred: 12.4831 - val_loss: 127.2278 - val_mean_pred: 35.6542 - val_std_pred: 12.7303
# Epoch 91/100
#  - 0s - loss: 119.6769 - mean_pred: 35.4958 - std_pred: 12.4827 - val_loss: 126.5979 - val_mean_pred: 35.7103 - val_std_pred: 12.7987
# Epoch 92/100
#  - 0s - loss: 119.6195 - mean_pred: 35.7428 - std_pred: 12.5712 - val_loss: 126.3138 - val_mean_pred: 35.8719 - val_std_pred: 12.8943
# Epoch 93/100
#  - 0s - loss: 118.9143 - mean_pred: 35.7521 - std_pred: 12.3691 - val_loss: 125.8728 - val_mean_pred: 35.8714 - val_std_pred: 12.8664
# Epoch 94/100
#  - 0s - loss: 118.6558 - mean_pred: 35.7960 - std_pred: 12.5911 - val_loss: 125.7462 - val_mean_pred: 35.9142 - val_std_pred: 12.8382
# Epoch 95/100
#  - 0s - loss: 118.2576 - mean_pred: 35.6656 - std_pred: 12.4577 - val_loss: 125.4238 - val_mean_pred: 35.7370 - val_std_pred: 12.7756
# Epoch 96/100
#  - 0s - loss: 117.9791 - mean_pred: 35.7593 - std_pred: 12.4742 - val_loss: 125.2295 - val_mean_pred: 35.8357 - val_std_pred: 12.8019
# Epoch 97/100
#  - 0s - loss: 117.5746 - mean_pred: 35.7242 - std_pred: 12.3619 - val_loss: 124.8648 - val_mean_pred: 35.8638 - val_std_pred: 12.7779
# Epoch 98/100
#  - 0s - loss: 117.3275 - mean_pred: 35.8589 - std_pred: 12.4035 - val_loss: 124.3998 - val_mean_pred: 35.9654 - val_std_pred: 12.8304
# Epoch 99/100
#  - 0s - loss: 117.0875 - mean_pred: 35.8036 - std_pred: 12.5352 - val_loss: 124.2119 - val_mean_pred: 35.8641 - val_std_pred: 12.7557
# Epoch 100/100
#  - 0s - loss: 116.6916 - mean_pred: 35.5906 - std_pred: 12.4330 - val_loss: 123.7645 - val_mean_pred: 35.6984 - val_std_pred: 12.7474

# %%
## the mean of Step B and Step C are close. There was probably no need to increase epochs to 100, we could have the similar result with 50.
